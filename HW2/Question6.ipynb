# %%
import numpy as np

# %%
#Function that returns the next state and reward
#The function takes as input the current state and the action performed
def get_next_state_and_reward(row, col, action):       
    #All other cases are uniform. The action variable denotes up,left,down or right
    x = col + action[0]
    y = row + action[1]
    state = index_map[row][col]
    
    #If the object doesn't fall of the grid, the reward is 0 and state is updated
    if (x > -1 and x < 4) and (y > - 1 and y < 4):
        state = index_map[y][x]
    reward = -1
    return state, reward

def are_similar(a,b):
    for i in range(len(a)):
        if a[i] == 0 and b[i] == 0:
            continue
        elif (a[i] == 0):
            return False
        elif (b[i] == 0):
            return False
        pass
    return True

# %% [markdown]
# ## Policy Iteration

# %%
#Create an index map to uniquely identify each cell in the grid with a single number
index_map = [[(i + 4*j) for i in range(4)] for j in range(5)]

#Value function for all the states
value_states = [0 for i in range(16)]

#Possible Actions
allowed = [[-1,0],[1,0],[0,-1],[0,1]]
actions = {0 : "Left", 1 : "Right", 2 : "Up", 3 : "Down" }

#The limit when we want our algorithm to break
theta = 0.0001

#Assuming a stochastic problem
pi = np.zeros((16,4))
pi.fill(0.25)

# %% [markdown]
# ### To fix the bug mentioned in the question, i took a stochastic setting and created an array to store p(a|s) for each of the 4 action

# %%
while True:
    while True:
        delta = 0
        for row in range(4):
            for col in range(4):
                #Get the state s
                cur = index_map[row][col]
                
                #Skip the terminal states
                if cur == 0 or cur == 15:
                    continue
                
                #Get current value of V(s)
                v_cur = value_states[cur]
                v_new = 0
                action_counter = 0
                
                #Iterate over all actions
                
                for action in allowed:
                    #Get the next state and corresponding reward (s', r)
                    next_, reward = get_next_state_and_reward(row, col, action) 
                    
                    #For each action sum over p(s|a) * 1.0 * (r + v(s'))
                    v_new += pi[cur][action_counter] * 1.0 * (reward + value_states[next_]) 
                    
                    action_counter += 1
                print ("Updated Value of State " + str(cur) + " From " + str(v_cur) + " To " + str(v_new))
                
                #Update the value of V(s)
                value_states[cur] = v_new
                
                #Check the level of update
                delta = max(delta, abs(v_cur - v_new))
        if delta < theta:
            break
    
    policy_stable = True
    for row in range(4):
        for col in range(4):
            cur = index_map[row][col]
            if cur == 0 or cur == 15:
                continue
            #Get the current probabilities for each action
            pi_cur = pi[cur].copy()
            q_temp = []
            
            #Setup new probabilities
            pi_new = np.zeros(4)
            
            for action in allowed:
                next_, reward = get_next_state_and_reward(row, col, action)
                #Store new values of q(s,a)
                q_temp.append(reward + value_states[next_])
                
            #BUG FIX - Get all the actions which have same maximum q
            optim_actions = np.argwhere(q_temp == np.amax(q_temp))
            optim_actions = optim_actions.flatten().tolist()
            
            #Number of optimal actions
            num = len(optim_actions)
            
            #p(a|s) = 1/num optimal
            pi_new[optim_actions] = 1.0/num
            
            #Update this value for all actions
            pi[cur] = pi_new
            if not are_similar(pi_cur, pi_new):
                policy_stable = False
    if (policy_stable):
        break
# Out:
# Updated Value of State 1 From 0 To -1.0
# Updated Value of State 2 From 0 To -1.25
# Updated Value of State 3 From 0 To -1.3125
# Updated Value of State 4 From 0 To -1.0
# Updated Value of State 5 From 0 To -1.5
# Updated Value of State 6 From 0 To -1.6875
# Updated Value of State 7 From 0 To -1.75
# Updated Value of State 8 From 0 To -1.25
# Updated Value of State 9 From 0 To -1.6875
# Updated Value of State 10 From 0 To -1.84375
# Updated Value of State 11 From 0 To -1.8984375
# Updated Value of State 12 From 0 To -1.3125
# Updated Value of State 13 From 0 To -1.75
# Updated Value of State 14 From 0 To -1.8984375
# Updated Value of State 1 From -1.0 To -1.9375
# Updated Value of State 2 From -1.25 To -2.546875
# Updated Value of State 3 From -1.3125 To -2.73046875
# Updated Value of State 4 From -1.0 To -1.9375
# Updated Value of State 5 From -1.5 To -2.8125
# Updated Value of State 6 From -1.6875 To -3.23828125
# Updated Value of State 7 From -1.75 To -3.404296875
# Updated Value of State 8 From -1.25 To -2.546875
# Updated Value of State 9 From -1.6875 To -3.23828125
# Updated Value of State 10 From -1.84375 To -3.568359375
# Updated Value of State 11 From -1.8984375 To -3.2177734375
# Updated Value of State 12 From -1.3125 To -2.73046875
# Updated Value of State 13 From -1.75 To -3.404296875
# Updated Value of State 14 From -1.8984375 To -3.2177734375
# Updated Value of State 1 From -1.9375 To -2.82421875
# Updated Value of State 2 From -2.546875 To -3.8349609375
# Updated Value of State 3 From -2.73046875 To -4.175048828125
# Updated Value of State 4 From -1.9375 To -2.82421875
# Updated Value of State 5 From -2.8125 To -4.03125
# Updated Value of State 6 From -3.23828125 To -4.709716796875
# Updated Value of State 7 From -3.404296875 To -4.876708984375
# Updated Value of State 8 From -2.546875 To -3.8349609375
# Updated Value of State 9 From -3.23828125 To -4.709716796875
# Updated Value of State 10 From -3.568359375 To -4.9637451171875
# Updated Value of State 11 From -3.2177734375 To -4.264556884765625
# Updated Value of State 12 From -2.73046875 To -4.175048828125
# Updated Value of State 13 From -3.404296875 To -4.876708984375
# Updated Value of State 14 From -3.2177734375 To -4.264556884765625
# Updated Value of State 1 From -2.82421875 To -3.672607421875
# Updated Value of State 2 From -3.8349609375 To -5.09808349609375
# Updated Value of State 3 From -4.175048828125 To -5.5812225341796875
# Updated Value of State 4 From -2.82421875 To -3.672607421875
# Updated Value of State 5 From -4.03125 To -5.191162109375
# Updated Value of State 6 From -4.709716796875 To -6.0324249267578125
# Updated Value of State 7 From -4.876708984375 To -6.188728332519531
# Updated Value of State 8 From -3.8349609375 To -5.09808349609375
# Updated Value of State 9 From -4.709716796875 To -6.0324249267578125
# Updated Value of State 10 From -4.9637451171875 To -6.148490905761719
# Updated Value of State 11 From -4.264556884765625 To -5.150444030761719
# Updated Value of State 12 From -4.175048828125 To -5.5812225341796875
# Updated Value of State 13 From -4.876708984375 To -6.188728332519531
# Updated Value of State 14 From -4.264556884765625 To -5.150444030761719
# Updated Value of State 1 From -3.672607421875 To -4.4904632568359375
# Updated Value of State 2 From -5.09808349609375 To -6.300548553466797
# Updated Value of State 3 From -5.5812225341796875 To -6.912930488586426
# Updated Value of State 4 From -3.672607421875 To -4.4904632568359375
# Updated Value of State 10 From -17.999079072848808 To -17.999156254598965
# Updated Value of State 11 From -13.999312424461952 To -13.99937004930592
# Updated Value of State 12 From -21.998703837036732 To -21.99881246682994
# Updated Value of State 13 From -19.99892109662315 To -19.999011518162757
# Updated Value of State 14 From -13.999312424461952 To -13.999370049305917
# Updated Value of State 1 From -13.99924952837585 To -13.999312424461952
# Updated Value of State 2 From -19.99892109662315 To -19.999011518162757
# Updated Value of State 3 From -21.998812466829943 To -21.99891199249635
# Updated Value of State 4 From -13.99924952837585 To -13.999312424461952
# Updated Value of State 5 From -17.999079072848808 To -17.999156254598965
# Updated Value of State 6 From -19.99900008473598 To -19.99908388638086
# Updated Value of State 7 From -19.999011518162757 To -19.999094361586472
# Updated Value of State 8 From -19.99892109662315 To -19.999011518162753
# Updated Value of State 9 From -19.99900008473598 To -19.99908388638086
# Updated Value of State 10 From -17.999156254598965 To -17.99922696784339
# Updated Value of State 11 From -13.99937004930592 To -13.999422844683945
# Updated Value of State 12 From -21.99881246682994 To -21.998911992496346
# Updated Value of State 13 From -19.999011518162757 To -19.99909436158647
# Updated Value of State 14 From -13.999370049305917 To -13.999422844683943
# Updated Value of State 1 From -13.999312424461952 To -1.0
# Updated Value of State 2 From -19.999011518162757 To -2.0
# Updated Value of State 3 From -21.99891199249635 To -3.0
# Updated Value of State 4 From -13.999312424461952 To -1.0
# Updated Value of State 5 From -17.999156254598965 To -2.0
# Updated Value of State 6 From -19.99908388638086 To -3.0
# Updated Value of State 7 From -19.999094361586472 To -14.999422844683945
# Updated Value of State 8 From -19.999011518162753 To -2.0
# Updated Value of State 9 From -19.99908388638086 To -3.0
# Updated Value of State 10 From -17.99922696784339 To -14.999422844683943
# Updated Value of State 11 From -13.999422844683945 To -1.0
# Updated Value of State 12 From -21.998911992496346 To -3.0
# Updated Value of State 13 From -19.99909436158647 To -14.999422844683943
# Updated Value of State 14 From -13.999422844683943 To -1.0
# Updated Value of State 1 From -1.0 To -1.0
# Updated Value of State 2 From -2.0 To -2.0
# Updated Value of State 3 From -3.0 To -3.0
# Updated Value of State 4 From -1.0 To -1.0
# Updated Value of State 5 From -2.0 To -2.0
# Updated Value of State 6 From -3.0 To -3.0
# Updated Value of State 7 From -14.999422844683945 To -2.0
# Updated Value of State 8 From -2.0 To -2.0
# Updated Value of State 9 From -3.0 To -3.0
# Updated Value of State 10 From -14.999422844683943 To -2.0
# Updated Value of State 11 From -1.0 To -1.0
# Updated Value of State 12 From -3.0 To -3.0
# Updated Value of State 13 From -14.999422844683943 To -2.0
# Updated Value of State 14 From -1.0 To -1.0
# Updated Value of State 1 From -1.0 To -1.0
# Updated Value of State 2 From -2.0 To -2.0
# Updated Value of State 3 From -3.0 To -3.0
# Updated Value of State 4 From -1.0 To -1.0
# Updated Value of State 5 From -2.0 To -2.0
# Updated Value of State 6 From -3.0 To -3.0
# Updated Value of State 7 From -2.0 To -2.0
# Updated Value of State 8 From -2.0 To -2.0
# Updated Value of State 9 From -3.0 To -3.0
# Updated Value of State 10 From -2.0 To -2.0
# Updated Value of State 11 From -1.0 To -1.0
# Updated Value of State 12 From -3.0 To -3.0
# Updated Value of State 13 From -2.0 To -2.0
# Updated Value of State 14 From -1.0 To -1.0
# Updated Value of State 1 From -1.0 To -1.0
# Updated Value of State 2 From -2.0 To -2.0
# Updated Value of State 3 From -3.0 To -3.0
# Updated Value of State 4 From -1.0 To -1.0
# Updated Value of State 5 From -2.0 To -2.0
# Updated Value of State 6 From -3.0 To -3.0
# Updated Value of State 7 From -2.0 To -2.0
# Updated Value of State 8 From -2.0 To -2.0
# Updated Value of State 9 From -3.0 To -3.0
# Updated Value of State 10 From -2.0 To -2.0
# Updated Value of State 11 From -1.0 To -1.0
# Updated Value of State 12 From -3.0 To -3.0
# Updated Value of State 13 From -2.0 To -2.0
# Updated Value of State 14 From -1.0 To -1.0

# %%
value_states[:]
# Out:
# [0,
#  -1.0,
#  -2.0,
#  -3.0,
#  -1.0,
#  -2.0,
#  -3.0,
#  -2.0,
#  -2.0,
#  -3.0,
#  -2.0,
#  -1.0,
#  -3.0,
#  -2.0,
#  -1.0,
#  0]

# %%
ans = [["" for i in range(4)] for j in range(4)]
for i in range(4):
    for j in range(4):
        cur = index_map[i][j]
        fav_actions = pi[cur]
        st = ""
        for k in range(4):
            if fav_actions[k] > 0:
                st += actions[k] + " "
        ans[i][j] = st
ans
# Out:
# [['Left Right Up Down ', 'Left ', 'Left ', 'Left Down '],
#  ['Up ', 'Left Up ', 'Left Right Up Down ', 'Down '],
#  ['Up ', 'Left Right Up Down ', 'Right Down ', 'Down '],
#  ['Right Up ', 'Right ', 'Right ', 'Left Right Up Down ']]

# %% [markdown]
# ## Value Iteration

# %%
#Create an index map to uniquely identify each cell in the grid with a single number
index_map = [[(i + 4*j) for i in range(4)] for j in range(5)]

#Value function for all the states
value_states = [0 for i in range(16)]

#Possible Actions
allowed = [[-1,0],[1,0],[0,-1],[0,1]]

#The limit when we want our algorithm to break
theta = 0.0001

pi = np.zeros((16,4))
pi.fill(0.25)

# %%
#The code here is same as above, except we use a max function to get the maximum q
while True:
    delta = 0
    for row in range(4):
        for col in range(4):
            cur = index_map[row][col]
            if cur == 0 or cur == 15:
                continue
            v_cur = value_states[cur]
            q_temp = []
            for action in allowed:
                next_, reward = get_next_state_and_reward(row, col, action) 
                q_temp.append(reward + value_states[next_])
            #CHANGE
            v_new = max(q_temp)
            print ("Updated Value of State " + str(cur) + " From " + str(v_cur) + " To " + str(v_new))
            value_states[cur] = v_new
            delta = max(delta, abs(v_cur - v_new))
    if delta < theta:
        break
for row in range(4):
    for col in range(4):
        cur = index_map[row][col]
        if cur == 0 or cur == 15:
            continue
        pi_cur = pi[cur].copy()
        q_temp = []
        pi_new = np.zeros(4)
        action_counter = 0
        for action in allowed:
            next_, reward = get_next_state_and_reward(row, col, action)
            q_temp.append(reward + value_states[next_])
        optim_actions = np.argwhere(q_temp == np.amax(q_temp))
        optim_actions = optim_actions.flatten().tolist()
        num = len(optim_actions)
        pi_new[optim_actions] = 1.0/num
        pi[cur] = pi_new
# Out:
# Updated Value of State 1 From 0 To -1
# Updated Value of State 2 From 0 To -1
# Updated Value of State 3 From 0 To -1
# Updated Value of State 4 From 0 To -1
# Updated Value of State 5 From 0 To -1
# Updated Value of State 6 From 0 To -1
# Updated Value of State 7 From 0 To -1
# Updated Value of State 8 From 0 To -1
# Updated Value of State 9 From 0 To -1
# Updated Value of State 10 From 0 To -1
# Updated Value of State 11 From 0 To -1
# Updated Value of State 12 From 0 To -1
# Updated Value of State 13 From 0 To -1
# Updated Value of State 14 From 0 To -1
# Updated Value of State 1 From -1 To -1
# Updated Value of State 2 From -1 To -2
# Updated Value of State 3 From -1 To -2
# Updated Value of State 4 From -1 To -1
# Updated Value of State 5 From -1 To -2
# Updated Value of State 6 From -1 To -2
# Updated Value of State 7 From -1 To -2
# Updated Value of State 8 From -1 To -2
# Updated Value of State 9 From -1 To -2
# Updated Value of State 10 From -1 To -2
# Updated Value of State 11 From -1 To -1
# Updated Value of State 12 From -1 To -2
# Updated Value of State 13 From -1 To -2
# Updated Value of State 14 From -1 To -1
# Updated Value of State 1 From -1 To -1
# Updated Value of State 2 From -2 To -2
# Updated Value of State 3 From -2 To -3
# Updated Value of State 4 From -1 To -1
# Updated Value of State 5 From -2 To -2
# Updated Value of State 6 From -2 To -3
# Updated Value of State 7 From -2 To -2
# Updated Value of State 8 From -2 To -2
# Updated Value of State 9 From -2 To -3
# Updated Value of State 10 From -2 To -2
# Updated Value of State 11 From -1 To -1
# Updated Value of State 12 From -2 To -3
# Updated Value of State 13 From -2 To -2
# Updated Value of State 14 From -1 To -1
# Updated Value of State 1 From -1 To -1
# Updated Value of State 2 From -2 To -2
# Updated Value of State 3 From -3 To -3
# Updated Value of State 4 From -1 To -1
# Updated Value of State 5 From -2 To -2
# Updated Value of State 6 From -3 To -3
# Updated Value of State 7 From -2 To -2
# Updated Value of State 8 From -2 To -2
# Updated Value of State 9 From -3 To -3
# Updated Value of State 10 From -2 To -2
# Updated Value of State 11 From -1 To -1
# Updated Value of State 12 From -3 To -3
# Updated Value of State 13 From -2 To -2
# Updated Value of State 14 From -1 To -1

# %%
value_states
# Out:
# [0, -1, -2, -3, -1, -2, -3, -2, -2, -3, -2, -1, -3, -2, -1, 0]

# %%
ans = [["" for i in range(4)] for j in range(4)]
for i in range(4):
    for j in range(4):
        cur = index_map[i][j]
        fav_actions = pi[cur]
        st = ""
        for k in range(4):
            if fav_actions[k] > 0:
                st += actions[k] + " "
        ans[i][j] = st
ans
# Out:
# [['Left Right Up Down ', 'Left ', 'Left ', 'Left Down '],
#  ['Up ', 'Left Up ', 'Left Right Up Down ', 'Down '],
#  ['Up ', 'Left Right Up Down ', 'Right Down ', 'Down '],
#  ['Right Up ', 'Right ', 'Right ', 'Left Right Up Down ']]

# %% [markdown]
# ### We obtain the same results using both the methods
